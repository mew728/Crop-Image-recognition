# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import numpy as np
import cv2
import scipy.misc
import os, shutil
from google.colab.patches import cv2_imshow

# %%
# original_ZIP = r'/content/gdrive/MyDrive/Colab Notebooks/2713-AI/origin/banana' 

# put=r'/content/gdrive/MyDrive/Colab Notebooks/AI/pic_t'

# def inputimange(classname,fnames,old):
#   for fname in fnames:
#     src = os.path.join(original_ZIP,old)
#     dst = os.path.join(classname, fname)
#     shutil.copyfile(src, dst)
# fnames = ['banana.{}.jpg'.format(i) for i in range(0,4)] #format格式 (i)->{}.format(i)
# old= []
# for x in range(0,4):
  
# inputimange(put, fnames) #train

# %% [markdown]
# #Create file

# %%
# 用來儲存少量資料集的目錄位置
createfile= r'/content/gdrive/MyDrive/Colab Notebooks/Aidea/data' 
if not os.path.isdir(createfile): os.mkdir(createfile)  # 如果目錄不存在, 才建立目錄
###############################################################################################################################
# 訓練集
train_dir = os.path.join(createfile, 'test_cut')
if not os.path.isdir(train_dir): os.mkdir(train_dir)
train_1 = os.path.join(train_dir, 'banana')
if not os.path.isdir(train_1): os.mkdir(train_1) # 用來訓練貓圖片的目錄位置
train_1 = os.path.join(train_dir, 'carrot')
if not os.path.isdir(train_1): os.mkdir(train_1) # 用來訓練貓圖片的目錄位置
train_1 = os.path.join(train_dir, 'corn')
if not os.path.isdir(train_1): os.mkdir(train_1) # 用來訓練貓圖片的目錄位置
train_1 = os.path.join(train_dir, 'dragonfruit')
if not os.path.isdir(train_1): os.mkdir(train_1) # 用來訓練貓圖片的目錄位置
train_1 = os.path.join(train_dir, 'garlic')
if not os.path.isdir(train_1): os.mkdir(train_1) # 用來訓練貓圖片的目錄位置
train_1 = os.path.join(train_dir, 'guava')
if not os.path.isdir(train_1): os.mkdir(train_1) # 用來訓練貓圖片的目錄位置
train_1 = os.path.join(train_dir, 'peanut')
if not os.path.isdir(train_1): os.mkdir(train_1) # 用來訓練貓圖片的目錄位置
train_1 = os.path.join(train_dir, 'pineapple')
if not os.path.isdir(train_1): os.mkdir(train_1) # 用來訓練貓圖片的目錄位置
train_1 = os.path.join(train_dir, 'pumpkin')
if not os.path.isdir(train_1): os.mkdir(train_1) # 用來訓練貓圖片的目錄位置
train_1 = os.path.join(train_dir, 'rice')
if not os.path.isdir(train_1): os.mkdir(train_1) # 用來訓練貓圖片的目錄位置
train_1 = os.path.join(train_dir, 'soybean')
if not os.path.isdir(train_1): os.mkdir(train_1) # 用來訓練貓圖片的目錄位置
train_1 = os.path.join(train_dir, 'sugarcane')
if not os.path.isdir(train_1): os.mkdir(train_1) # 用來訓練貓圖片的目錄位置
train_1 = os.path.join(train_dir, 'tomato')
if not os.path.isdir(train_1): os.mkdir(train_1) # 用來訓練貓圖片的目錄位置
train_1 = os.path.join(train_dir, 'bareland')
if not os.path.isdir(train_1): os.mkdir(train_1) # 用來訓練貓圖片的目錄位置

# %% [markdown]
# #Picture copy
# banana:4077
# carrot:1991
# corn:9665
# dragonfruit:1957
# garlic:7652
# guava:4719
# peanut:10523
# pineapple:8002
# pumpkin:1676
# rice:7950
# soybean:5683
# sugarcane:2223
# tomato:1503
# bareland:3477

# %%
# import os
# import numpy
# import cv2
# def is_inp(name):
#     return(name[-4:] in ['.jpg','.JPG', '.jpeg', '.JPEG', '.png', '.PNG'])

# # print(is_inp('/content/gdrive/MyDrive/Colab Notebooks/AI/pic_t/roro0.jpg'))
# input_path = '/content/gdrive/MyDrive/Colab Notebooks/2713-AI/origin/banana'
# all_inputs = os.listdir(input_path)
# all_inputs.sort()
# all_inp = [i for i in (all_inputs[x] for x in range(0,4) ) if is_inp(i)]

# print(all_inp)
# for i in range(len(all_inp)):
#     path_=os.path.join(input_path,all_inp[i])  
#     I=cv2.imread(path_)
#     cv2.imwrite('/content/gdrive/MyDrive/Colab Notebooks/AI/pic_t/'+'banana{}'.format(i)+'.jpg',I)
# Out:
# ['160107-3-0035.JPG', '160107-3-0039.JPG', '160107-3-0273.JPG', '160107-3-0320.JPG']

# %%
# a=["banana", "carrot", "corn", "dragonfruit", "garlic", "guava", "peanut", "pineapple", "pumpkin", "rice", "soybean", "sugarcane", "tomato", "bareland"]
a= [ "guava", "peanut", "pineapple", "pumpkin", "rice", "soybean", "sugarcane", "tomato", "bareland"]
for name in a :
  def is_inp(name):
      return(name[-4:] in ['.jpg','.JPG', '.jpeg', '.JPEG', '.png', '.PNG'])

  input_path = '/content/gdrive/MyDrive/Colab Notebooks/2713-AI/origin/'+name
  all_inputs = os.listdir(input_path)
  all_inputs.sort()
  try:  
    all_inp = [i for i in (all_inputs[x] for x in range(0,1201) ) if is_inp(i)] #1504
    for i in range(len(all_inp)):
        path_=os.path.join(input_path,all_inp[i])  
        I=cv2.imread(path_)
        cv2.imwrite('/content/gdrive/MyDrive/Colab Notebooks/Aidea/data/train/'+name+'/'+name+'{}'.format(i)+'.jpg',I)   
  except:
    print("no enough")
    continue
  # print(name+':'+str(len(all_inputs)))

# %%
a=["banana", "carrot", "corn", "dragonfruit", "garlic", "guava", "peanut", "pineapple", "pumpkin", "rice", "soybean", "sugarcane", "tomato", "bareland"]

for name in a :
  def is_inp(name):
      return(name[-4:] in ['.jpg','.JPG', '.jpeg', '.JPEG', '.png', '.PNG'])

  input_path = '/content/gdrive/MyDrive/Colab Notebooks/2713-AI/origin/'+name
  all_inputs = os.listdir(input_path)
  all_inputs.sort()
  try:  
    all_inp = [i for i in (all_inputs[x] for x in range(1000,1200) ) if is_inp(i)] #1504
    for i in range(len(all_inp)):
        path_=os.path.join(input_path,all_inp[i])  
        I=cv2.imread(path_)
        cv2.imwrite('/content/gdrive/MyDrive/Colab Notebooks/Aidea/data/test_o/'+name+'/'+name+'{}'.format(i)+'.jpg',I)   
  except:
    print("no enough")
    continue
  # print(name+':'+str(len(all_inputs)))
# Out:
# no enough

# %% [markdown]
# # 九宮格

# %%
# def cut_image(image):
# #獲取圖片的寬和高
# width,height = image.size
# #計算1/3的寬
# item_width = int(width / 3)
# #計算1/3的高
# item_height = int(height / 3)
# #使用倆個循環的切割圖片，將圖片切割爲9份
# for i in range(0,3):
# for j in range(0,3):
# #計算每一個子圖片的切割位置
# split_data = (j * item_width,i * item_height
# ,(j+1) * item_width,(i+1) * item_height)
# #切割對應的子圖片，並按照順序保存至文件中
# image.crop(split_data).save(
# '/share/image/' + str(j+1 + 3 * i) + '.png',"PNG")

# %%
def is_inp(name):
    return(name[-4:] in ['.jpg','.JPG', '.jpeg', '.JPEG', '.png', '.PNG'])

# print(is_inp('/content/gdrive/MyDrive/Colab Notebooks/AI/pic_t/roro0.jpg'))
input_path = '/content/gdrive/MyDrive/Colab Notebooks/2713-AI/origin/banana'
all_inputs = os.listdir(input_path)
all_inputs.sort()
all_inp = [i for i in (all_inputs[x] for x in range(0,1) ) if is_inp(i)]

print(all_inp)

def cut(pic):
  pic_shape = pic.shape
  h = pic_shape[0]/3
  w = pic_shape[1]/3
  print(h,w)

  afdata= pic[int(h*0.8):int(h+h*1.2),int(w*0.8):int(w+w*1.2)]
  # print(afdata)
  afdata = cv2.resize(afdata,(224,224))
  cv2_imshow(afdata)


# https://blog.csdn.net/weixin_43289135/article/details/107645007


for i in range(len(all_inp)):
    path_=os.path.join(input_path,all_inp[i])  
    I=cv2.imread(path_)
    cut(I)
    # cv2_imshow(I)
    # cv2.imwrite('/content/gdrive/MyDrive/Colab Notebooks/AI/pic_t/'+'banana{}'.format(i)+'.jpg',I)
# Out:
# ['160107-3-0035.JPG']
# 816.0 1088.0
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FFB3558A310>

# %%
a=["banana", "carrot"]

for name in a :
  def is_inp(name):
      return(name[-4:] in ['.jpg','.JPG', '.jpeg', '.JPEG', '.png', '.PNG'])

  input_path = '/content/gdrive/MyDrive/Colab Notebooks/2713-AI/origin/'+name
  all_inputs = os.listdir(input_path)
  all_inputs.sort()

  try:  
    all_inp = [i for i in (all_inputs[x] for x in range(0,300) ) if is_inp(i)] #撈多少筆
    # 
    def cut(pic):
      pic_shape = pic.shape
      h = pic_shape[0]/3
      w = pic_shape[1]/3

      afdata= pic[int(h*0.8):int(h+h*1.2),int(w*0.8):int(w+w*1.2)]
      # print(afdata)
      afdata = cv2.resize(afdata,(224,224))
      # cv2_imshow(afdata)

      return afdata

    for i in range(len(all_inp)): #名字i源自於此
        path_=os.path.join(input_path,all_inp[i])  
        I=cv2.imread(path_)
        I=cut(I)
        cv2_imshow(I)
        # cv2.imwrite('/content/gdrive/MyDrive/Colab Notebooks/Aidea/data/test/'+name+'/'+name+'{}'.format(i)+'.jpg',I)   
  except:
    print("no enough")
    continue
  # print(name+':'+str(len(all_inputs)))
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FFB3551F510>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FFB3551F510>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FFB3E4726D0>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FFB35545A90>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FFB3552C390>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FFB40577D50>

# %% [markdown]
# #reshape

# %%
def is_inp(name):
    return(name[-4:] in ['.jpg','.JPG', '.jpeg', '.JPEG', '.png', '.PNG'])


input_path = '/content/gdrive/MyDrive/Colab Notebooks/2713-AI/origin/banana'
all_inputs = os.listdir(input_path)
all_inputs.sort()
all_inp = [i for i in (all_inputs[x] for x in range(0,2) ) if is_inp(i)]

print(all_inp)

for i in range(len(all_inp)):
    path_=os.path.join(input_path,all_inp[i])  
    I=cv2.imread(path_)
    I = cv2.resize(I,(224,224))
    cv2_imshow(I)
# Out:
# ['160107-3-0035.JPG', '160107-3-0039.JPG']
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FFB3F4C23D0>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FFB4A0267D0>

# %% [markdown]
# #finally

# %%
a=["banana", "carrot", "corn", "dragonfruit", "garlic", "guava", "peanut", "pineapple", "pumpkin", "rice", "soybean", "sugarcane", "tomato", "bareland"]

for name in a :
  def is_inp(name):
      return(name[-4:] in ['.jpg','.JPG', '.jpeg', '.JPEG', '.png', '.PNG'])

  input_path = '/content/gdrive/MyDrive/Colab Notebooks/2713-AI/origin/'+name
  all_inputs = os.listdir(input_path)
  all_inputs.sort()

  try:  
    all_inp = [i for i in (all_inputs[x] for x in range(0,500) ) if is_inp(i)] #撈多少筆
    # 
    def cut(pic):
      pic_shape = pic.shape
      h = pic_shape[0]/3
      w = pic_shape[1]/3

      afdata= pic[int(h*0.8):int(h+h*1.2),int(w*0.8):int(w+w*1.2)]
      # print(afdata)
      afdata = cv2.resize(afdata,(224,224))
      # cv2_imshow(afdata)

      return afdata

    for i in range(len(all_inp)): #名字i源自於此
        path_=os.path.join(input_path,all_inp[i])  
        I=cv2.imread(path_)
        I=cut(I)
        cv2.imwrite('/content/gdrive/MyDrive/Colab Notebooks/Aidea/data/train/'+name+'/'+name+'_cut{}'.format(i)+'.jpg',I)  #test/train 
        # cv2.imwrite('/content/gdrive/MyDrive/Colab Notebooks/AI/pic_t/'+name+'_cut{}'.format(i)+'.jpg',I)  
         
  except:
    print(name+"..fail")
    continue
  # print(name+':'+str(len(all_inputs)))
  print(name+"..ok")
# Out:
# banana..ok
# carrot..ok
# corn..ok
# dragonfruit..ok
# garlic..ok
# guava..ok
# peanut..ok
# pineapple..ok
# pumpkin..ok
# rice..ok
# soybean..ok
# sugarcane..ok
# tomato..ok
# bareland..ok

# %%
a=["soybean", "sugarcane", "tomato", "bareland"]
# ["banana", "carrot", "corn", "dragonfruit", "garlic", "guava", "peanut", "pineapple", "pumpkin", "rice", 
for name in a :
  def is_inp(name):
      return(name[-4:] in ['.jpg','.JPG', '.jpeg', '.JPEG', '.png', '.PNG'])

  input_path = '/content/gdrive/MyDrive/Colab Notebooks/2713-AI/origin/'+name
  all_inputs = os.listdir(input_path)
  all_inputs.sort()

  try:  
    all_inp = [i for i in (all_inputs[x] for x in range(1000,1200) ) if is_inp(i)] #撈多少筆
    # 
    def cut(pic):
      pic_shape = pic.shape
      h = pic_shape[0]/3
      w = pic_shape[1]/3

      afdata= pic[int(h*0.8):int(h+h*1.2),int(w*0.8):int(w+w*1.2)]
      # print(afdata)
      afdata = cv2.resize(afdata,(224,224))
      # cv2_imshow(afdata)

      return afdata

    for i in range(len(all_inp)): #名字i源自於此
        path_=os.path.join(input_path,all_inp[i])  
        I=cv2.imread(path_)
        I=cut(I)
        cv2.imwrite('/content/gdrive/MyDrive/Colab Notebooks/Aidea/data/test_cut/'+name+'/'+name+'_test{}'.format(i)+'.jpg',I)  #test/train 
        # cv2.imwrite('/content/gdrive/MyDrive/Colab Notebooks/AI/pic_t/'+name+'_cut{}'.format(i)+'.jpg',I)  
         
  except:
    print(name+"..fail")
    continue
  # print(name+':'+str(len(all_inputs)))
  print(name+"..ok")
# Out:
# soybean..ok
# sugarcane..ok
# tomato..ok
# bareland..ok

# %%
a=["banana", "carrot", "corn", "dragonfruit", "garlic", "guava", "peanut", "pineapple", "pumpkin", "rice", "soybean", "sugarcane", "tomato", "bareland"]

for name in a :
  def is_inp(name):
      return(name[-4:] in ['.jpg','.JPG', '.jpeg', '.JPEG', '.png', '.PNG'])

  input_path = '/content/gdrive/MyDrive/Colab Notebooks/2713-AI/origin/'+name
  all_inputs = os.listdir(input_path)
  all_inputs.sort()

  try:  
    all_inp = [i for i in (all_inputs[x] for x in range(1000,1200) ) if is_inp(i)] #撈多少筆
    # 
    for i in range(len(all_inp)): #名字i源自於此
        path_=os.path.join(input_path,all_inp[i])  
        I=cv2.imread(path_)
        I = cv2.resize(I,(224,224))
        cv2.imwrite('/content/gdrive/MyDrive/Colab Notebooks/Aidea/data/test_o/'+name+'/'+name+'{}'.format(i)+'.jpg',I)  #test/train 
        # cv2.imwrite('/content/gdrive/MyDrive/Colab Notebooks/AI/pic_t/'+name+'_cut{}'.format(i)+'.jpg',I)  
         
  except:
    print(name+"..fail")
    continue
  # print(name+':'+str(len(all_inputs)))
  print(name+"..ok")
# Out:
# banana..ok
# carrot..ok
# corn..ok
# dragonfruit..ok
# garlic..ok
# guava..ok
# peanut..ok
# pineapple..ok
# pumpkin..ok
# rice..ok
# soybean..ok
# sugarcane..ok
# tomato..ok
# bareland..ok
